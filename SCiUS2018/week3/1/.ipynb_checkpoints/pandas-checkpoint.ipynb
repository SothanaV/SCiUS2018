# %%
import pandas as pd
x = pd.read_csv('data.csv')
df = pd.DataFrame(x)

win8 = df['Windows 8'].values.tolist()
win10 = df['Windows 10'].values.tolist()
date = df['Year-Month'].values.tolist()

# %%
print(x)
# Out:
#     Year-Month Windows 8 Windows XP Windows 10 Windows Vista Windows 7  \
# 0      2003-01        0%     17.42%         0%            0%        0%
# 1      2003-02        0%     18.78%         0%            0%        0%
# 2      2003-03        0%     20.52%         0%            0%        0%
# 3      2003-04        0%     21.94%         0%            0%        0%
# 4      2003-05        0%     23.38%         0%            0%        0%
# 5      2003-06        0%     24.53%         0%            0%        0%
# 6      2003-07        0%     26.52%         0%            0%        0%
# 7      2003-08        0%     28.15%         0%            0%        0%
# 8      2003-09        0%     30.03%         0%            0%        0%
# 9      2003-10        0%     32.78%         0%            0%        0%
# 10     2003-11        0%     33.54%         0%            0%        0%
# 11     2003-12        0%     35.34%         0%            0%        0%
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(60,40))
plt.plot(date,win8, date,win10)
plt.show()
