# %%
'''
01_line

sample python

'''

from turtle import *

forward(100)

exitonclick()

# %%
'''
    triangle
'''
from turtle import *

forward(100)
right(120)
forward(100)
right(120)
forward(100)
right(120)


exitonclick()

# %%
'''
ADD COLOR
add (outline,fill)
  https://htmlcolorcodes.com/
color('red', 'yellow')

'''

from turtle import *
color('red', 'yellow')
begin_fill()
forward(100)
right(120)
forward(100)
right(120)
forward(100)
right(120)
end_fill()

exitonclick()

# %%
'''
02_triangle

function

'''

from turtle import *
def tri(size):
    forward(size)
    right(120)
    forward(size)
    right(120)
    forward(size)
    right(120)
    
tri(50)


exitonclick()

# %%
'''
03_square Fn
'''


from turtle import *
def square(size):
    forward(size)
    right(90)
    forward(size)
    right(90)
    forward(size)
    right(90)
    forward(size)
    right(90)
    
square(50)


exitonclick()

# %%
'''
04_triangle-for loop
'''

from turtle import *
def tri(size):
    for i in range(3):
        forward(size)
        right(120)
        
tri(50)

exitonclick()

# %%
'''
05_square-for loop
'''

from turtle import *
def square(size):
    for i in range(4):
        forward(size)
        right(90)
        
square(50)

exitonclick()

# %%
'''
06_geo 
'''

from turtle import *
def geo(size,n):
    for i in range(n):
        forward(size)
        right(360/n)
geo(0.5,6)

exitonclick()

# %%
'''
07_turtle !!!can Skip!!!

For Loop again
'''

from turtle import *
forward(100)
left(30)
for i in range(3):
    forward(100)
    right(120)
    
exitonclick()

# %%
'''
08_function

Fn and For loop

'''
from turtle import *
def leaf():
    forward(100)
    left(30)
    for i in range(3):
        forward(100)
        right(120)
        
leaf()

exitonclick()

# %%
'''
# !!!can Skip!!!
'''

from turtle import *
def leaf():
    forward(100)
    left(30)
    for i in range(3):
        forward(100)
        right(120)
    right(30)
    backward(100)
    right(90)
    
leaf()
leaf()

exitonclick()

# %%
'''
# !!!can Skip!!!
'''

from turtle import *
def leaf(size):
    forward(size)
    left(30)
    for i in range(3):
        forward(size)
        right(120)
        
leaf(100)

exitonclick()

# %%
'''
11_leaf-arg set0
set 0 at setpos

'''

from turtle import *

def leaf(size):
    init_pos=pos()
    init_head=heading()
    forward(size)
    left(30)
    for i in range(3):
        forward(size)
        right(120)
    setpos(init_pos)
    setheading(init_head)
    
leaf(100)

exitonclick()

# %%
'''
12_branch Fn call Fn

'''

from turtle import *

def branch(size):
    init_pos=pos()
    init_head=heading()
    forward(size*0.75)
    left(45)
    for i in range(3):
        leaf(size*0.25)
        right(45)
    setpos(init_pos)
    setheading(init_head)
def leaf(size):
    init_pos=pos()
    init_head=heading()
    forward(size)
    left(30)
    for i in range(3):
        forward(size)
        right(120)
    setpos(init_pos)
    setheading(init_head)

branch(100)

exitonclick()

# %%
'''
fn in fn in fn
'''
from turtle import *

def tree(size):
    left(90)
    init_pos=pos()
    init_head=heading()
    forward(size*0.5)
    left(45)
    for i in range(3):
        branch(size*0.5)
        right(45)
    setpos(init_pos)
    setheading(init_head)
def branch(size):
    init_pos=pos()
    init_head=heading()
    forward(size*0.75)
    left(45)
    for i in range(3):
        leaf(size*0.25)
        right(45)
    setpos(init_pos)
    setheading(init_head)
def leaf(size):
    init_pos=pos()
    init_head=heading()
    forward(size)
    left(30)
    for i in range(3):
        forward(size)
        right(120)
    setpos(init_pos)
    setheading(init_head)

tree(50)


exitonclick()

# %%
'''
Hard
'''

from turtle import *
def branch(size):
    if size<2:
        return
    else:
        forward(size*0.4)
        init_pos=pos()
        init_head=heading()
        
        left(15)
        forward(size*0.5)
        branch(size*0.5)
        
        penup()
        setpos(init_pos)
        setheading(init_head)
        pendown()
        
        right(20)
        forward(size*0.5)
        branch(size*0.5)
        
        penup()
        setpos(init_pos)
        setheading(init_head)
        pendown()
        
size=128
penup()
setpos((0,-size))
setheading(90)
pendown()
branch(size)
setpos((0,-size))

exitonclick()

# %%
'''
circle(radius)

'''
from turtle import *

circle(10)

exitonclick()
